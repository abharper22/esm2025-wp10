# %%
from scipy.io import netcdf

import iris
import iris.coord_categorisation

import os
import logging

import numpy as np

import pickle
from pathlib import Path
logger = logging.getLogger(__name__)

# %%
def get_scenarios(LSM):
    """
    Return a List containing SCENARIO tag names, not including the 
    no land use change scenarios. The land use scenario 
    names depend on the LSM. For now it will only return two climate
    scenarios (some models additionally ran 585). 

    Parameters
    ----------
    LSM : str
        Which land surface model is being run. Options are ``'clm'``,
        ``'jules'``, ``'orchidee'``, or ``'jsbach'``.

    Returns
    -------
    SCENARIO_TITLES: character
    PLOT_TITLES: character
    CLIM_SCENARIOS: character
    CLIM_MODELS: character      
    """
    CLIM_SCENARIOS = [ 'ssp126', 'ssp370' ]
    CLIM_MODELS = [ 'mpi-esm1-2-hr','ukesm1-0-ll','ipsl-cm6a-lr' ]

    if LSM=='clm':
        SCENARIO_TITLES = ['agtobio', 'agtonat', 'agtoaff', 'nattobio', 'nattoaff']
        PLOT_TITLES = ['Biocrops on ag land', 'Natural regrowth on ag land', 
                   'Afforestation on ag land', 'Biocrops on natural land',
                   'Afforestation on natural land']         
    elif LSM=='jules':
        SCENARIO_TITLES = ['agtobio', 'agtonat', 'agtoaff', 'nattobio', 'nattoaff']
        PLOT_TITLES = ['Biocrops on ag land', 'Natural regrowth on ag land', 
                   'Afforestation on ag land', 'Biocrops on natural land',
                   'Afforestation on natural land']
    elif LSM=='orchidee':
        SCENARIO_TITLES = ['agtoaff','nattoaff']
        PLOT_TITLES = ['Afforestation on ag land', 'Afforestation on natural land']         
    elif LSM=='jsbach':
        SCENARIO_TITLES = ['agtobio', 'agtoaff', 'nattobio']
        PLOT_TITLES = ['Biocrops on ag land',  
                   'Afforestation on ag land', 'Biocrops on natural land']        
    else:
        print('get_scenarios is not set up for this model:',LSM)
        
    return SCENARIO_TITLES, PLOT_TITLES, CLIM_SCENARIOS, CLIM_MODELS

# %%
def add_metadata(cube, field, fname):

    lsm_id = fname.split('/')[4]
    if lsm_id=='orchidee':
        esm_id = fname.split('_')[3]
        ssp_id = fname.split('_')[4]
    elif lsm_id=='analysis':
        esm_id = fname.split('_')[2]
        ssp_id = fname.split('_')[3]
    else:
        esm_id = fname.split('_')[1]
        ssp_id = fname.split('_')[2]
    iris.std_names.STD_NAMES['experiment_id'] = {'canonical units':'1'}
    
    #if not cube.coords("experiment_id"):
    climate_coord = iris.coords.AuxCoord(ssp_id, "experiment_id", units="1", long_name="experiment_id")
    cube.add_aux_coord(climate_coord)

    #if not cube.coords("realization"):
    esm_coord = iris.coords.AuxCoord(esm_id, "realization", units="1")
    cube.add_aux_coord(esm_coord)

# %%
def _get_land_fraction(cube):
    """Extract land fraction as :mod:`dask.array`."""
    fx_cube = None
    land_fraction = None
    errors = []
    
    try:
        fx_cube = cube.ancillary_variable('land_area_fraction')
    except iris.exceptions.AncillaryVariableNotFoundError:
        try:
            fx_cube = cube.ancillary_variable('sea_area_fraction')
        except iris.exceptions.AncillaryVariableNotFoundError:
            errors.append('Ancillary variables land/sea area fraction not '
                          'found in cube. Check ancillary data availability.')
            return (land_fraction, errors)

    land_fraction = fx_cube.core_data()
    
    if fx_cube.var_name == 'sftlf':
        land_fraction = fx_cube.core_data() / 100.0
    if fx_cube.var_name == 'sftof':
        land_fraction = 1.0 - fx_cube.core_data() / 100.0
    
    return (land_fraction, errors)

# %%
def weighting_landsea_fraction(cube, area_type, apply_mask_only):
    """Weight fields using land or sea fraction.

    This preprocessor function weights a field with its corresponding land or
    sea area fraction (value between 0 and 1). The application of this is
    important for most carbon cycle variables (and other land-surface outputs),
    which are e.g. reported in units of `kgC m-2`. This actually refers to 'per
    square meter of land/sea' and NOT 'per square meter of gridbox'. So in
    order to integrate these globally or regionally one has to both area-weight
    the quantity but also weight by the land/sea fraction.

    Parameters
    ----------
    cube : iris.cube.Cube
        Data cube to be weighted. It should have an
        :class:`iris.coords.AncillaryVariable` with standard name
        ``'land_area_fraction'`` or ``'sea_area_fraction'``. If both are
        present, only the ``'land_area_fraction'`` will be used.
    area_type : str
        Use land (``'land'``) or sea (``'sea'``) fraction for weighting.
    apply_mask_only : bool
        If True: mask out ocean points as missing (Needed for climate data
        that exists everywhere. The LSM output is on land only already.)
        Don't weight by fraction of grid cell that is land in coastal areas.

    Returns
    -------
    iris.cube.Cube
        Land/sea fraction weighted cube.

    Raises
    ------
    TypeError
        ``area_type`` is not ``'land'`` or ``'sea'``.
    ValueError
        Land/sea fraction variables ``sftlf`` or ``sftof`` not found.
    """
    if area_type not in ('land', 'sea'):
        raise TypeError(
            f"Expected 'land' or 'sea' for area_type, got '{area_type}'")
    (land_fraction, errors) = _get_land_fraction(cube)
    if land_fraction is None:
        raise ValueError(
            f"Weighting of '{cube.var_name}' with '{area_type}' fraction "
            f"failed because of the following errors: {' '.join(errors)}")

    core_data = cube.core_data()
    if apply_mask_only:
        #print('before land mask, min and max of cube:')
        #print(np.min(cube.data),np.max(cube.data))
        dims=np.shape(cube.data)
        ntime=dims[0]
        # for 90x180 dimensions, this returns about 70% of all points as masked
        land_fraction = np.ma.masked_values(land_fraction,0)
        land_mask_3d = np.ma.stack([land_fraction] * ntime)
        nmasked1 = np.ma.count_masked(land_mask_3d)
        #print(nmasked1)
        cube.data = np.ma.masked_where(np.ma.getmask(land_mask_3d),cube.data)
        #This works!
        nmasked2 = np.ma.count_masked(cube.data)
        #print(nmasked2)
        #print(land_fraction)
        #print(np.min(land_fraction),np.max(land_fraction))
        #print('after land mask, min and max of cube:')
        #print(np.min(cube.data),np.max(cube.data))
        del(land_mask_3d)
        
    else:
        if area_type == 'land':
            cube.data = core_data * land_fraction
        elif area_type == 'sea':
            cube.data = core_data * (1.0 - land_fraction)
    return cube

# %%
def add_ancillary_variable(cube, temp_ancil_cube):
    """Add cube as an ancillary variable in the cube containing the data.

    Parameters
    ----------
    cube: iris.cube.Cube
        Iris cube with input data.
    temp_ancil_cube: iris.cube.Cube
        Iris cube with ancillary data.

    Returns
    -------
    iris.cube.Cube
        Cube with added ancillary variables
    """
    
    cube_left_lat = cube.coord("longitude").points[0]
    cube_right_lat = cube.coord("longitude").points[-1]

    acube_left_lat = temp_ancil_cube.coord("longitude").points[0]
    acube_right_lat = temp_ancil_cube.coord("longitude").points[-1]

    if cube_left_lat != acube_left_lat:
        ancillary_cube = temp_ancil_cube.intersection(longitude=(-180,180), ignore_bounds=True )
    else:
        ancillary_cube = temp_ancil_cube
        
    ancillary_var = iris.coords.AncillaryVariable(
        ancillary_cube.core_data(),
        standard_name=ancillary_cube.standard_name,
        units=ancillary_cube.units,
        var_name=ancillary_cube.var_name,
        attributes=ancillary_cube.attributes)
    start_dim = cube.ndim - len(ancillary_var.shape)
    cube.add_ancillary_variable(ancillary_var, range(start_dim, cube.ndim))
    logger.debug('Added %s as ancillary variable in cube of %s.',
                 ancillary_cube.var_name, cube.var_name)

# %%
def weighting_pft_fraction(cube,ssp,esm,LU_SCENARIO):
    var = 'landCoverFrac'

    ncfile1 = Dataset('/bdd/ESM2025/WP10/analysis/scripts/mask_latlon2d.nc', 'r')
    lons = ncfile1.variables['lon']
    lats = ncfile1.variables['lat']
    land_fraction = ncfile1.variables['land_sea_mask']

    ncfile2=Dataset('/bdd/ESM2025/WP10/jules/jules_'+esm+'_'+ssp+'_'+LU_SCENARIO+\
            '_landCoverFrac.monthly.nc', 'r')    
    
    if LU_SCENARIO == 'nolucbio' or LU_SCENARIO == 'nattobio' or LU_SCENARIO == 'agtobio':
        npft = 14
        pfts = ['BET-Tr', 'BET-Te', 'BDT', 'NET', 
                'NDT','C3G(nat)', 'C3G(crop)', 'C3G(past)', 
                'C4G(nat)','C4G(crop)', 'C4G(past)', 'ESh', 
                'DSh', 'Misc(bio)']
    else:
        npft = 22
        pfts = ['BET-Tr', 'BET-Te', 'BDT', 'NET', 
                'NDT','C3G(nat)', 'C3G(crop)', 'C3G(past)', 
                'C4G(nat)','C4G(crop)', 'C4G(past)', 'ESh', 
                'DSh', 'BET-Tr(bio)', 'BET-Te(bio)', 'BDT(bio)', 
                'NET(bio)', 'NDT(bio)','C3G(bio)', 'C4G(bio)',
                'ESh(bio)', 'DSh(bio)']

    fracs = ncfile2.variables['landCoverFrac'][:,0:npft,:,:]        

    core_data = cube.core_data()
    cube.data = core_data * fracs

    return cube

# %%
def retrieve_map_data(var,LU_SCENARIO,LSM):
    """Get the maps of the first and last time step.

    Parameters
    ----------
    var: character
        The variable to retrieve (cSoil and cVeg).
    LU_SCENARIO: character
        The land use scenario.
    LSM: character
        The land surface model (jules, clm, orchidee, jsbach)

    Returns
    -------
    FIRST_YEAR_MAP, LAST_YEAR_MAP
        Dictionary with the gridded outputs for mapping.
    """
    
    firstmap_file = Path('/bdd/ESM2025/WP10/analysis/files/'+LSM+'_'+var+'_'+LU_SCENARIO+'_2015.pkl')
    lastmap_file = Path('/bdd/ESM2025/WP10/analysis/files/'+LSM+'_'+var+'_'+LU_SCENARIO+'_2100.pkl')

    if firstmap_file.is_file():
        # file exists, we can skip a bunch of steps:
        # print('read pickle files',my_file)
        with open(firstmap_file, 'rb') as f1:
            FIRST_YEAR_MAP = pickle.load(f1)
        with open(lastmap_file, 'rb') as f2:
            LAST_YEAR_MAP = pickle.load(f2)
            
    return FIRST_YEAR_MAP, LAST_YEAR_MAP

# %%
def get_filenames(var,LU_SCENARIO,LSM,ssp):
    if LSM=='orchidee':
        filenames = ['/bdd/ESM2025/WP10/'+LSM+'/mpi-esm1-2-hr_'+ssp+'_'+LU_SCENARIO+'/'+LSM+'_mpi-esm1-2-hr_'+ssp+'_'+LU_SCENARIO+'_'+var+'.nc',
                     '/bdd/ESM2025/WP10/'+LSM+'/ukesm1-0-ll_'+ssp+'_'+LU_SCENARIO+'/'+LSM+'_ukesm1-0-ll_'+ssp+'_'+LU_SCENARIO+'_'+var+'.nc',
                     '/bdd/ESM2025/WP10/'+LSM+'/ipsl-cm6a-lr_'+ssp+'_'+LU_SCENARIO+'/'+LSM+'_ipsl-cm6a-lr_'+ssp+'_'+LU_SCENARIO+'_'+var+'.nc']
    elif LSM=='jsbach':
        filenames = ['/bdd/ESM2025/WP10/'+LSM+'/'+LU_SCENARIO+'/JSBACH3_mpi-esm1-2-hr_'+ssp+'_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/'+LSM+'/'+LU_SCENARIO+'/JSBACH3_ukesm1-0-ll_'+ssp+'_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/'+LSM+'/'+LU_SCENARIO+'/JSBACH3_ipsl-cm6a-lr_'+ssp+'_'+LU_SCENARIO+'_'+var+'.monthly.nc']    
    else:
        filenames = ['/bdd/ESM2025/WP10/'+LSM+'/'+LSM+'_mpi-esm1-2-hr_'+ssp+'_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/'+LSM+'/'+LSM+'_ukesm1-0-ll_'+ssp+'_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/'+LSM+'/'+LSM+'_ipsl-cm6a-lr_'+ssp+'_'+LU_SCENARIO+'_'+var+'.monthly.nc']
    if LSM=='jules' and var=='TotalAlbedo':
        filenames = ['/bdd/ESM2025/WP10/analysis/jules_albedo/jules_mpi-esm1-2-hr_'+ssp+'_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/analysis/jules_albedo/jules_ukesm1-0-ll_'+ssp+'_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/analysis/jules_albedo/jules_ipsl-cm6a-lr_'+ssp+'_'+LU_SCENARIO+'_'+var+'.monthly.nc']
    elif LSM=='jules' and var=='rn':
        filenames = ['/bdd/ESM2025/WP10/analysis/jules_rn/jules_mpi-esm1-2-hr_'+ssp+'_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/analysis/jules_rn/jules_ukesm1-0-ll_'+ssp+'_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/analysis/jules_rn/jules_ipsl-cm6a-lr_'+ssp+'_'+LU_SCENARIO+'_'+var+'.monthly.nc'] 
     
    return filenames

# %%
def get_landfrac(LSM):
    if LSM=='jules':
        land_frac = iris.load_cube('/bdd/ESM2025/WP10/analysis/scripts/mask_latlon2d.nc','land_sea_mask')
        land_frac.standard_name='land_area_fraction'
    elif LSM=='clm':
        land_frac = iris.load_cube('/bdd/ESM2025/WP10/analysis/scripts/clm_landfrac.nc','landfrac')
        land_frac.standard_name='land_area_fraction'
    elif LSM=='orchidee':
        land_frac = iris.load_cube('/bdd/ESM2025/WP10/analysis/scripts/orchidee_oceanCoverFrac_notime.nc','oceanCoverFrac')
        land_frac.standard_name='land_area_fraction' #the fact that its sea is accounted for below
    elif LSM=='jsbach':
        land_frac = iris.load_cube(\
                '/bdd/ESM2025/WP10/jsbach/hist/JSBACH3_ukesm1-0-ll_hist_hist_oceanCoverFrac.once.nc',
                'oceanCoverFrac')
        #0=ocean; 1=land
        land_frac.standard_name='land_area_fraction'
    
    return land_frac

# %%
def get_lsm_data(lsm):
    if lsm=='jules':
        ncfile1 = Dataset('/bdd/ESM2025/WP10/analysis/scripts/mask_latlon2d.nc', 'r')
        lons = ncfile1.variables['lon']
        lats = ncfile1.variables['lat']
        temparray = ncfile1.variables['land_sea_mask']
        
        land_fraction=np.empty_like(temparray)
        land_fraction[:,:90] = temparray[:,90:]
        land_fraction[:,90:] = temparray[:,:90]
        del(temparray)        
    elif lsm=='clm':
        ncfile1 = Dataset('/bdd/ESM2025/WP10/analysis/scripts/clm_landfrac.nc', 'r')
        lons = ncfile1.variables['lon']
        lats = ncfile1.variables['lat']
        land_fraction = ncfile1.variables['landfrac']
    elif lsm=='orchidee':
        ncfile1 = Dataset('/bdd/ESM2025/WP10/analysis/scripts/orchidee_oceanCoverFrac_notime.nc', 'r')
        lons = ncfile1.variables['longitude']
        lats = ncfile1.variables['latitude']
        #0=ocean; 1=land
        ocean_frac = ncfile1.variables['oceanCoverFrac']
        ones = np.ones_like(ocean_frac)
        land_fraction = ones - ocean_frac        
        del(ones, ocean_frac)
    elif lsm=='jsbach':
        ncfile1 = Dataset('/bdd/ESM2025/WP10/jsbach/hist/JSBACH3_ukesm1-0-ll_hist_hist_oceanCoverFrac.once.nc', 'r')
        lons = ncfile1.variables['lon']
        lats = ncfile1.variables['lat']
        #lats=np.flip(lats,0)
            
        #0=ocean; 1=land
        ocean_frac = ncfile1.variables['oceanCoverFrac']
        ones = np.ones_like(ocean_frac)
        land_fraction = ones - ocean_frac  
        del(ones, ocean_frac)
    else:
        print('Incorrect name for LSM in get_lsm_data')

    return land_fraction, lons, lats

# %%
def get_lsm_fracs(inputdata,ctrl_data,lsm,esm,ssp,landuse,calc_delta,noluc_only):
    if lsm=='jules':
        #print('mask JULES')
        #print('min/max of input data:',np.min(inputdata),np.max(inputdata))
        fFile_scenario='/bdd/ESM2025/WP10/jules/jules_'+esm+'_'+ssp+'_'+\
                        landuse+'_landCoverFrac.monthly.nc'
        fFile_noluc='/bdd/ESM2025/WP10/jules/jules_'+esm+'_'+ssp+\
                        '_nolucbio_landCoverFrac.monthly.nc'    
        ncfile_scenario=Dataset(fFile_scenario, 'r')
        ncfile_noluc=Dataset(fFile_noluc, 'r')
        fracs_scenario = ncfile_scenario.variables['landCoverFrac'][:,13,:,:]
        fracs_noluc = ncfile_noluc.variables['landCoverFrac'][:,13,:,:]
        diff=fracs_scenario-fracs_noluc                        
        threshold = 2e-6
        #print('min/max of diff for BE fracs:',np.min(diff),np.max(diff))
        # Mask the input dataset, return a copy (so original data is not altered)
        model_mask = np.ma.masked_where(diff < threshold, inputdata, True)
        
        if calc_delta:
            output_data = model_mask - np.ma.masked_where(diff < threshold, ctrl_data, True)
        elif noluc_only:
            output_data = np.ma.masked_where(diff < threshold, ctrl_data, True)
        else:
            output_data = model_mask
        #print('min/max of output data:',np.min(model_mask),np.max(model_mask))
        
        del(fracs_scenario, fracs_noluc, diff, model_mask)
        #print(model_mask.shape)
    elif lsm=='jsbach':
        #print('mask JSBACH')
        fFile_scenario='/bdd/ESM2025/WP10/jsbach/'+landuse+'/'+\
                            'JSBACH3_'+esm+'_'+ssp+'_'+landuse+'_landCoverFrac.monthly.nc'
        fFile_noluc='/bdd/ESM2025/WP10/jsbach/noluc/'+\
                            'JSBACH3_'+esm+'_'+ssp+'_noluc_landCoverFrac.monthly.nc'
        ncfile_scenario=Dataset(fFile_scenario, 'r')
        ncfile_noluc=Dataset(fFile_noluc, 'r')

        fracs_scenario = ncfile_scenario.variables['landCoverFrac'][:,11,:,:]
        fracs_noluc = ncfile_noluc.variables['landCoverFrac'][:,11,:,:]
        diff=fracs_scenario-fracs_noluc            
        threshold = 0.01
        model_mask = np.ma.masked_where(diff < threshold, inputdata, True)
        if calc_delta:
            output_data = model_mask - np.ma.masked_where(diff < threshold, ctrl_data, True)
        elif noluc_only:
            output_data = np.ma.masked_where(diff < threshold, ctrl_data, True)
        else:
            output_data = model_mask
            
        del(model_mask, fracs_scenario, fracs_noluc, diff)
        #print(model_mask.shape)
    elif lsm=='clm':
        #print('mask CLM')
        fFile_scenario='/bdd/ESM2025/WP10/clm/clm_'+esm+'_'+ssp+'_'+\
                          landuse+'_landCoverFrac.monthly.nc'
        fFile_noluc='/bdd/ESM2025/WP10/clm/clm_'+esm+'_'+ssp+'_'+\
                          'noluc_landCoverFrac.monthly.nc'
        ncfile_scenario=Dataset(fFile_scenario, 'r')
        ncfile_noluc=Dataset(fFile_noluc, 'r')

        fracs_scenario = ncfile_scenario.variables['landCoverFrac'][:,71:75,:,:]
        fracs_noluc = ncfile_noluc.variables['landCoverFrac'][:,71:75,:,:]
                    
        diff = np.zeros([1032,96,144])
        diff = np.sum(fracs_scenario,axis=1)-np.sum(fracs_noluc,axis=1)
        array_3d_stack = np.stack([diff[0,:,:]] * 1032)
        threshold = 0.01
        model_mask = np.ma.masked_where(array_3d_stack < threshold, inputdata, True)     
        if calc_delta:
            output_data = model_mask - np.ma.masked_where(array_3d_stack < threshold, ctrl_data, True)
        elif noluc_only:
            output_data = np.ma.masked_where(array_3d_stack < threshold, ctrl_data, True)
        else:
            output_data = model_mask
        del(model_mask, fracs_scenario, fracs_noluc, diff, array_3d_stack)
        #print(model_mask.shape)    

    
    return(output_data)

# %%
def retrieve_data_generic(var,units,LU_SCENARIO,LSM):
    """Get the outputs from the netcdf files and compute annual means.

    Parameters
    ----------
    var: character
        The variable to retrieve (cSoil and cVeg).
    units: character
        Tells us if we need to do any unit conversions.
    LU_SCENARIO: character
        The land use scenario.
    LSM: character
        The land surface model (jules, clm, orchidee, jsbach)

    Returns
    -------
    ENSEMBLE_MEAN
        Dictionary with the global, annual mean outputs for plotting.
    """
    
    dum1,dum2,ssp, esm = get_scenarios(LSM)

    path = ''

    nclim = len(esm)
    years = np.arange(2015,2101)
    
    if model=='jules' and var=='TotalAlbedo':
        filenames = ['/bdd/ESM2025/WP10/analysis/jules_albedo/jules_mpi-esm1-2-hr_ssp126_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/analysis/jules_albedo/jules_ukesm1-0-ll_ssp126_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/analysis/jules_albedo/jules_ipsl-cm6a-lr_ssp126_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/analysis/jules_albedo/jules_mpi-esm1-2-hr_ssp370_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/analysis/jules_albedo/jules_ukesm1-0-ll_ssp370_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/analysis/jules_albedo/jules_ipsl-cm6a-lr_ssp370_'+LU_SCENARIO+'_'+var+'.monthly.nc']
    elif model=='jules' and var=='rn':
        filenames = ['/bdd/ESM2025/WP10/analysis/jules_rn/jules_mpi-esm1-2-hr_ssp126_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/analysis/jules_rn/jules_ukesm1-0-ll_ssp126_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/analysis/jules_rn/jules_ipsl-cm6a-lr_ssp126_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/analysis/jules_rn/jules_mpi-esm1-2-hr_ssp370_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/analysis/jules_rn/jules_ukesm1-0-ll_ssp370_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/analysis/jules_rn/jules_ipsl-cm6a-lr_ssp370_'+LU_SCENARIO+'_'+var+'.monthly.nc'] 
    else:
        filenames = ['/bdd/ESM2025/WP10/'+LSM+'/'+LSM+'_mpi-esm1-2-hr_ssp126_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/'+LSM+'/'+LSM+'_ukesm1-0-ll_ssp126_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/'+LSM+'/'+LSM+'_ipsl-cm6a-lr_ssp126_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/'+LSM+'/'+LSM+'_mpi-esm1-2-hr_ssp370_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/'+LSM+'/'+LSM+'_ukesm1-0-ll_ssp370_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/'+LSM+'/'+LSM+'_ipsl-cm6a-lr_ssp370_'+LU_SCENARIO+'_'+var+'.monthly.nc']
    if LSM=='orchidee':
        filenames = ['/bdd/ESM2025/WP10/'+LSM+'/mpi-esm1-2-hr_ssp126_'+LU_SCENARIO+'/'+LSM+'_mpi-esm1-2-hr_ssp126_'+LU_SCENARIO+'_'+var+'.nc',
                 '/bdd/ESM2025/WP10/'+LSM+'/ukesm1-0-ll_ssp126_'+LU_SCENARIO+'/'+LSM+'_ukesm1-0-ll_ssp126_'+LU_SCENARIO+'_'+var+'.nc',
                 '/bdd/ESM2025/WP10/'+LSM+'/ipsl-cm6a-lr_ssp126_'+LU_SCENARIO+'/'+LSM+'_ipsl-cm6a-lr_ssp126_'+LU_SCENARIO+'_'+var+'.nc',
                 '/bdd/ESM2025/WP10/'+LSM+'/mpi-esm1-2-hr_ssp370_'+LU_SCENARIO+'/'+LSM+'_mpi-esm1-2-hr_ssp370_'+LU_SCENARIO+'_'+var+'.nc',
                 '/bdd/ESM2025/WP10/'+LSM+'/ukesm1-0-ll_ssp370_'+LU_SCENARIO+'/'+LSM+'_ukesm1-0-ll_ssp370_'+LU_SCENARIO+'_'+var+'.nc',
                 '/bdd/ESM2025/WP10/'+LSM+'/ipsl-cm6a-lr_ssp370_'+LU_SCENARIO+'/'+LSM+'_ipsl-cm6a-lr_ssp370_'+LU_SCENARIO+'_'+var+'.nc']
    if LSM=='jsbach':
        filenames = ['/bdd/ESM2025/WP10/'+LSM+'/'+LU_SCENARIO+'/JSBACH3_mpi-esm1-2-hr_ssp126_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/'+LSM+'/'+LU_SCENARIO+'/JSBACH3_ukesm1-0-ll_ssp126_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/'+LSM+'/'+LU_SCENARIO+'/JSBACH3_ipsl-cm6a-lr_ssp126_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/'+LSM+'/'+LU_SCENARIO+'/JSBACH3_mpi-esm1-2-hr_ssp370_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/'+LSM+'/'+LU_SCENARIO+'/JSBACH3_ukesm1-0-ll_ssp370_'+LU_SCENARIO+'_'+var+'.monthly.nc',
                     '/bdd/ESM2025/WP10/'+LSM+'/'+LU_SCENARIO+'/JSBACH3_ipsl-cm6a-lr_ssp370_'+LU_SCENARIO+'_'+var+'.monthly.nc']        

    my_file = Path('/bdd/ESM2025/WP10/analysis/files/'+LSM+'_'+var+'_'+LU_SCENARIO+'.pkl')
    tropics_file = Path('/bdd/ESM2025/WP10/analysis/files/'+LSM+'_'+var+'_'+LU_SCENARIO+'_tropics.pkl')
    temperate_file = Path('/bdd/ESM2025/WP10/analysis/files/'+LSM+'_'+var+'_'+LU_SCENARIO+'_temp.pkl')
    firstmap_file = Path('/bdd/ESM2025/WP10/analysis/files/'+LSM+'_'+var+'_'+LU_SCENARIO+'_2015.pkl')
    lastmap_file = Path('/bdd/ESM2025/WP10/analysis/files/'+LSM+'_'+var+'_'+LU_SCENARIO+'_2100.pkl')

    if temperate_file.is_file():
        # file exists, we can skip a bunch of steps:
        # print('read pickle files',my_file)
        with open(my_file, 'rb') as f1:
            ENSEMBLE_MEAN = pickle.load(f1)
        with open(tropics_file, 'rb') as f2:
            TROPICS_MEAN = pickle.load(f2)
        with open(temperate_file, 'rb') as f3:    
            TEMPERATE_MEAN = pickle.load(f3)
  
    else:
        if LSM=='jules':
            land_frac = iris.load_cube('/bdd/ESM2025/WP10/analysis/scripts/mask_latlon2d.nc','land_sea_mask')
            land_frac.standard_name='land_area_fraction'
        elif LSM=='clm':
            land_frac = iris.load_cube('/bdd/ESM2025/WP10/analysis/scripts/clm_landfrac.nc','landfrac')
            land_frac.standard_name='land_area_fraction'
        elif LSM=='orchidee':
            land_frac = iris.load_cube('/bdd/ESM2025/WP10/analysis/scripts/orchidee_oceanCoverFrac_notime.nc','oceanCoverFrac')
            land_frac.standard_name='land_area_fraction' #the fact that its sea is accounted for below
        elif LSM=='jsbach':
            land_frac = iris.load_cube(\
                '/bdd/ESM2025/WP10/jsbach/hist/JSBACH3_ukesm1-0-ll_hist_hist_oceanCoverFrac.once.nc',
                'oceanCoverFrac')
            #0=ocean; 1=land
            land_frac.standard_name='land_area_fraction'
    
        
        # file doesn't exist, loop through scenarios and get data
        esms = iris.load(filenames, callback=add_metadata)
        ENSEMBLE_MEAN = {ssp_scen: {clim_mod: [] for clim_mod in esm} for ssp_scen in ssp}
        TROPICS_MEAN = {ssp_scen: {clim_mod: [] for clim_mod in esm} for ssp_scen in ssp}
        TEMPERATE_MEAN = {ssp_scen: {clim_mod: [] for clim_mod in esm} for ssp_scen in ssp}
        FIRST_TIMESTEP = {ssp_scen: {clim_mod: [] for clim_mod in esm} for ssp_scen in ssp}
        LAST_TIMESTEP = {ssp_scen: {clim_mod: [] for clim_mod in esm} for ssp_scen in ssp}

        tropics_start=0
        NHland_start=0
        NHland_end=0
        SPole_start=0
        if LSM=='jules':
            borderlat=23
        elif LSM=='clm':
            borderlat=25
        elif LSM=='orchidee':
            borderlat=23
        elif LSM=='jsbach':
            borderlat=25
        
        
        for ssp_id in ssp:
        
            for esm_id in esm:
                print(LSM,var,esm_id,ssp_id)
                esm_cube = esms.extract_cube(iris.Constraint(realization=esm_id,experiment_id=ssp_id) )
                #Mask biophysical variables and bioenergy harvests based on land area occupied by BE crops
                if (model=='jules' and var=='fBioHarvestpft'):
                    all_coord_names = [ coord.name() for coord in esm_cube.coords() ]
                    #print(all_coord_names)                    
                    
                    if(LU_SCENARIO=='agtobio' or LU_SCENARIO=='nattobio'):
                        esm_cube = esm_cube[:,13,:,:]
                        #approximation!
                        print('scale JULES')
                        fFile_scenario='/bdd/ESM2025/WP10/jules/jules_'+esm_id+'_'+ssp_id+'_'+\
                               LU_SCENARIO+'_landCoverFrac.monthly.nc'
                        fFile_noluc='/bdd/ESM2025/WP10/jules/jules_'+esm_id+'_'+ssp_id+\
                               '_nolucbio_landCoverFrac.monthly.nc'    
                        ncfile_scenario=Dataset(fFile_scenario, 'r')
                        ncfile_noluc=Dataset(fFile_noluc, 'r')
                        fracs_scenario = ncfile_scenario.variables['landCoverFrac'][:,13,:,:]
                        fracs_noluc = ncfile_noluc.variables['landCoverFrac'][:,13,:,:]
                        diff=fracs_scenario-fracs_noluc                        
                        threshold = 2e-6
                        print("mask jules where BE crops fraction is <",threshold)
                        esm_cube.data = np.ma.masked_where(diff.data < threshold, esm_cube.data)                        #esm_cube=esm_cube[:,13,:,:]#*fracs
                        del(fracs_noluc)
                        del(fracs_scenario)
                        del(diff)                    
                    else:
                        esm_cube=esm_cube[:,13,:,:]*0.0
                    #weighting_pft_fraction(esm_cube,ssp_id,esm_id,LU_SCENARIO)
                    #esm_cube=esm_cube.aggregated_by('pft',iris.analysis.SUM)

                elif (var=='rnpft' and model=='jules'):
                    frac_file='/bdd/ESM2025/WP10/jules/jules_'+esm_id+'_'+ssp_id+'_'+\
                               LU_SCENARIO+'_landCoverFrac.monthly.nc'
                    ncfile=Dataset(frac_file,'r')
                    fracs = ncfile.variables['landCoverFrac']
                    esm_cube=esm_cube*fracs
                    del(fracs)
                    
                elif (model=='jsbach' and var=='cHbpharv'):
                    fFile_scenario='/bdd/ESM2025/WP10/jsbach/'+LU_SCENARIO+'/'+\
                            'JSBACH3_'+esm_id+'_'+ssp_id+'_'+LU_SCENARIO+'_landCoverFrac.monthly.nc'
                    fFile_noluc='/bdd/ESM2025/WP10/jsbach/noluc/'+\
                            'JSBACH3_'+esm_id+'_'+ssp_id+'_noluc_landCoverFrac.monthly.nc'
                    ncfile_scenario=Dataset(fFile_scenario, 'r')
                    ncfile_noluc=Dataset(fFile_noluc, 'r')

                    fracs_scenario = ncfile_scenario.variables['landCoverFrac'][:,11,:,:]
                    fracs_noluc = ncfile_noluc.variables['landCoverFrac'][:,11,:,:]
                    diff=fracs_scenario-fracs_noluc
                    
                    threshold = 0.01
                    if var=='cHbpharv':
                        print("scale jsbach harvests")
                        esm_cube=esm_cube/diff
                        esm_cube.data = np.ma.masked_where(diff.data < threshold, esm_cube.data)
                    else:
                        print("mask land with <",threshold,"BE crops")
                        esm_cube.data = np.ma.masked_where(diff.data < threshold, esm_cube.data)
                    del(fracs_noluc, fracs_scenario, diff)
                
                elif (model=='clm' and var=='fHarvest'):
                    fFile_scenario='/bdd/ESM2025/WP10/clm/clm_'+esm_id+'_'+ssp_id+'_'+\
                          LU_SCENARIO+'_landCoverFrac.monthly.nc'
                    fFile_noluc='/bdd/ESM2025/WP10/clm/clm_'+esm_id+'_'+ssp_id+'_'+\
                          'noluc_landCoverFrac.monthly.nc'
                    ncfile_scenario=Dataset(fFile_scenario, 'r')
                    ncfile_noluc=Dataset(fFile_noluc, 'r')

                    fracs_scenario = ncfile_scenario.variables['landCoverFrac'][:,71:75,:,:]
                    fracs_noluc = ncfile_noluc.variables['landCoverFrac'][:,71:75,:,:]
                    
                    diff = np.zeros([1032,96,144])
                    diff=np.sum(fracs_scenario,axis=1)-np.sum(fracs_noluc,axis=1)
                    array_3d_stack = np.stack([diff[0,:,:]] * 1032)
                    threshold = 0.01
                    if var=='fHarvest':
                        print("scale & mask clm harvests")
                        esm_cube=esm_cube/array_3d_stack
                        esm_cube.data = np.ma.masked_where(array_3d_stack.data < threshold, esm_cube.data)
                    else:
                        print(var," mask land with <",threshold,"BE crops")
                        esm_cube.data = np.ma.masked_where(array_3d_stack.data < threshold, esm_cube.data)
                    del(fracs_noluc, fracs_scenario,diff,array_3d_stack)

                if LSM!='jsbach':
                    add_ancillary_variable(esm_cube,land_frac)
                
                try:
                    latcoord = esm_cube.coord("latitude")
                except:
                    latcoord = esm_cube.coord("lat")
                latcoord.units="degrees"
                try:
                    loncoord = esm_cube.coord("longitude")
                except:
                    loncoord = esm_cube.coord("lon")
                loncoord.units="degrees"        
    
                if tropics_start==0:
                    lats = latcoord.points
                    if LSM=='jsbach':
                        lats=np.flip(lats,0)
                    nlat = len(lats)
                    minlat=lats[0]
                    for i0 in range(nlat):
                        if lats[i0] > -25 and tropics_start==0:
                            tropics_start=i0
                            #print('beginning of tropics')
                        elif lats[i0] > borderlat and NHland_start==0:
                            tropics_end=i0
                            NHland_start=i0
                            #print('between tropics and temperate')
                        elif lats[i0] > 66 and NHland_end==0:
                            NHland_end=i0
                            #print('end of temperate zone')
                        elif lats[i0] > -58 and SPole_start==0:
                            SPole_start = i0
                            print('Only include points north of:',i0,lats[i0])
                print('double check zones','Tropics:',lats[tropics_start],lats[tropics_end-1],\
                      tropics_start,tropics_end,'Temperate:',lats[NHland_start],lats[NHland_end-1],\
                     NHland_start,NHland_end)
                
                tcoord = esm_cube.coord("time")
                if LSM=='clm':
                    tcoord.units="days since 2015-01-01 0:0:0"
                elif LSM=='jules':
                    tcoord.units="seconds since 2015-01-01 0:0:0"
                else:
                    tcoord.units="days since 2015-01-01 0:0:0"
                
                tcoord.calendar="calendar_no_leap"
                firstdate = tcoord.units.num2date(tcoord.points[0])
                iris.coord_categorisation.add_year(esm_cube,'time',name='year')        

                if units=='PgC':
                    if LSM=='jules' or LSM=='clm':
                        weighting_landsea_fraction(esm_cube, 'land', apply_mask_only=False)
                    elif LSM=='orchidee':
                        weighting_landsea_fraction(esm_cube, 'sea', apply_mask_only=False)

                #Previously the map routine was here.        
              
                #Next calculate the global total  
                if units=='PgC': 
                    #PgC: sum kgC/m2 over the globe, convert to PgC
                    #Calculates the annual mean from monthly values.
                    cveg_annual_map = esm_cube.aggregated_by('year',iris.analysis.MEAN)
                    cveg_annual_map.coord("latitude").guess_bounds()
                    cveg_annual_map.coord("longitude").guess_bounds() 

                    #normalise=False, weights are grid cell areas (default).
                    grid_areas = iris.analysis.cartography.area_weights(cveg_annual_map,normalize=False)
                    
                    constant_val=1.0e12
                    cveg_global = (cveg_annual_map.collapsed(["latitude","longitude"], iris.analysis.SUM, weights=grid_areas)/constant_val)
                    tropics = cveg_annual_map[:,tropics_start:tropics_end,:]
                    NHland = cveg_annual_map[:,NHland_start:NHland_end,:]
                    cveg_tropics = (tropics.collapsed(["latitude","longitude"], iris.analysis.SUM, weights=grid_areas[:,tropics_start:tropics_end,])/constant_val)
                    cveg_NHland = (NHland.collapsed(["latitude","longitude"], iris.analysis.SUM, weights=grid_areas[:,NHland_start:NHland_end,])/constant_val)
                    
                elif units=='kgC/m2/s':                
                    #fHarvest, eg. if wanting to get PgC
                    #JULES already in kgC/yr each month for fHarvest
                    #Otherwise need to convert from (per s) to (per yr)
                    if model=='jules' and var=='fBioHarvestpft':
                        constant_val=1.0e-12
                    else:
                        constant_val=86400*365/1.0e12
                    #Calculates the annual mean from monthly values.
                    cveg_annual_map = esm_cube.aggregated_by('year',iris.analysis.MEAN)
                    cveg_annual_map.coord("latitude").guess_bounds()
                    cveg_annual_map.coord("longitude").guess_bounds() 
                    #normalise=False, weights are grid cell areas (default).
                    grid_areas = iris.analysis.cartography.area_weights(cveg_annual_map,normalize=False)
                    
                    cveg_global = (cveg_annual_map.collapsed(["latitude","longitude"], iris.analysis.SUM, weights=grid_areas)*constant_val)
                    tropics = cveg_annual_map[:,tropics_start:tropics_end,:]
                    NHland = cveg_annual_map[:,NHland_start:NHland_end,:]
                    cveg_tropics = (tropics.collapsed(["latitude","longitude"], iris.analysis.SUM, weights=grid_areas[:,tropics_start:tropics_end,])*constant_val)
                    cveg_NHland = (NHland.collapsed(["latitude","longitude"], iris.analysis.SUM, weights=grid_areas[:,NHland_start:NHland_end,])*constant_val)
                elif units=='tC/ha':
                    #JULES already in kgC/yr each month for fHarvest
                    #Otherwise need to convert from (per s) to (per yr)
                    if model=='jsbach':
                        constant_val=10
                    elif model=='clm':
                        constant_val=10*365*86400
                    elif model=='jules':
                        constant_val=10*360/365

                    if model=='jsbach':
                        #Just get the December value each year
                        cveg_annual_map = esm_cube[11::12,:,:]
                        cveg_annual_map.coord("latitude").guess_bounds()
                        cveg_annual_map.coord("longitude").guess_bounds()                     
                    else:
                        #Calculates the annual mean from monthly values.
                        cveg_annual_map = esm_cube.aggregated_by('year',iris.analysis.MEAN)
                        cveg_annual_map.coord("latitude").guess_bounds()
                        cveg_annual_map.coord("longitude").guess_bounds() 
                
                    #normalise=False, weights are grid cell areas (default).
                    grid_areas = iris.analysis.cartography.area_weights(cveg_annual_map,normalize=False)                        
                    
                    #Mask locations with 0 bioenergy flux < 0.1 tC/ha/yr
                    threshold = 0.1 / constant_val
                    #cveg_annual_map.data = np.ma.masked_where(cveg_annual_map.data < threshold, cveg_annual_map.data)

                    cveg_global = (cveg_annual_map.collapsed(["latitude","longitude"], iris.analysis.MEAN, weights=grid_areas)*constant_val)
                    tropics = cveg_annual_map[:,tropics_start:tropics_end,:]
                    NHland = cveg_annual_map[:,NHland_start:NHland_end,:]

                    cveg_tropics = (tropics.collapsed(["latitude","longitude"], iris.analysis.MEAN, weights=grid_areas[:,tropics_start:tropics_end,])*constant_val)
                    cveg_NHland = (NHland.collapsed(["latitude","longitude"], iris.analysis.MEAN, weights=grid_areas[:,NHland_start:NHland_end,])*constant_val)                
                    
                    #cveg_tropics = (tropics.collapsed(["latitude","longitude"], iris.analysis.MEAN)*constant_val)
                    #cveg_NHland = (NHland.collapsed(["latitude","longitude"], iris.analysis.MEAN)*constant_val)
                    

                else:
                    #temperature, LH flux, precipitation: average
                    constant_val=1.0
                    #Calculates the annual mean from monthly values.
                    cveg_annual_map = esm_cube.aggregated_by('year',iris.analysis.MEAN)
                    cveg_annual_map.coord("latitude").guess_bounds()
                    cveg_annual_map.coord("longitude").guess_bounds() 
                    #normalise=False, weights are grid cell areas (default).
                    grid_areas = iris.analysis.cartography.area_weights(cveg_annual_map,normalize=False)
                    # Ignore Antarctica for energy budget calculations
                    if units=='W/m2' and model!='jules':
                        print('ignore Antarctica')
                        temp_global = cveg_annual_map[:,SPole_start:,:]
                        cveg_global = (temp_global.collapsed(["latitude","longitude"], \
                                                                 iris.analysis.MEAN, \
                                                                 weights=grid_areas[:,SPole_start:,])/constant_val)
                        del(temp_global)
                    else:
                        cveg_global = (cveg_annual_map.collapsed(["latitude","longitude"], \
                                                                 iris.analysis.MEAN, \
                                                                 weights=grid_areas)/constant_val)
                               
                    tropics = cveg_annual_map[:,tropics_start:tropics_end,:]
                    NHland = cveg_annual_map[:,NHland_start:NHland_end,:]
                    cveg_tropics = (tropics.collapsed(["latitude","longitude"], \
                                                      iris.analysis.MEAN, \
                                                      weights=grid_areas[:,tropics_start:tropics_end,])/constant_val)
                    cveg_NHland = (NHland.collapsed(["latitude","longitude"], \
                                                    iris.analysis.MEAN, \
                                                    weights=grid_areas[:,NHland_start:NHland_end,])/constant_val)

                FIRST_TIMESTEP[ssp_id][esm_id].append(cveg_annual_map[0,].core_data())
                LAST_TIMESTEP[ssp_id][esm_id].append(cveg_annual_map[-1,].core_data())
                
                #The data is lazy we need to make it real:
                cveg_global.data
                cveg_tropics.data
                cveg_NHland.data                
                
                #Calculate the mean across the 3 climate models for each SSP scenario.
                #ensemble_mean = cveg_global.collapsed("realization",iris.analysis.MEAN)
                ENSEMBLE_MEAN[ssp_id][esm_id].append(cveg_global.core_data())
                TROPICS_MEAN[ssp_id][esm_id].append(cveg_tropics.core_data())
                TEMPERATE_MEAN[ssp_id][esm_id].append(cveg_NHland.core_data())

        # If we've gone through this loop because the outputs files didn't exist:
        with open(my_file, 'wb') as f:
            pickle.dump(ENSEMBLE_MEAN, f)
        with open(tropics_file, 'wb') as f:
            pickle.dump(TROPICS_MEAN, f)            
        with open(temperate_file, 'wb') as f:
            pickle.dump(TEMPERATE_MEAN, f)        
        with open(firstmap_file, 'wb') as f2:
            pickle.dump(FIRST_TIMESTEP, f2)
        with open(lastmap_file, 'wb') as f3:
            pickle.dump(LAST_TIMESTEP, f3)

    return ENSEMBLE_MEAN,TROPICS_MEAN,TEMPERATE_MEAN
